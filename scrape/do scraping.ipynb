# %%
import urllib
import pandas as pd
testfile = urllib.URLopener()
testfile.retrieve("https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNYBROOK172&day=19&month=2&year=2016&dayend=20&monthend=3&yearend=2016&graphspan=custom&format=0", "KNYBOOK172.csv")
# Out:
# ('KNYBOOK172.csv', <httplib.HTTPMessage instance at 0x10b68ed40>)

# %%
pd.read_csv('list_PWS.csv')
# Out:
#                                         ﻿stationid_link stationid_link/_text  \
# 0     https://www.wunderground.com/weatherstation/WX...            KNYCITYI2
# 1     https://www.wunderground.com/weatherstation/WX...            KNYACCOR3
# 2     https://www.wunderground.com/weatherstation/WX...            KNYACCOR2
# 3     https://www.wunderground.com/weatherstation/WX...            KNYACCOR4
# 4     https://www.wunderground.com/weatherstation/WX...            KNYACCOR6
# 5     https://www.wunderground.com/weatherstation/WX...            KNYACCOR5
# 6     https://www.wunderground.com/weatherstation/WX...            KNYADAMS5
# 7     https://www.wunderground.com/weatherstation/WX...            KNYADAMS7
# 8     https://www.wunderground.com/weatherstation/WX...            KNYADAMS8
# 9     https://www.wunderground.com/weatherstation/WX...            KNYADDIS4
# 10    https://www.wunderground.com/weatherstation/WX...            KNYADDIS6
# ...

# %%
from bs4 import BeautifulSoup
import urllib
# r = urllib.urlopen('https://www.wunderground.com/personal-weather-station/dashboard?ID=KNYBRONX33#history/s20160219/e20160320/mmonth').read()
# soup = BeautifulSoup(r)
print type(soup)
# Out:
# <class 'bs4.BeautifulSoup'>
# /Users/mattia/anaconda/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]> <html class="no-js ie9"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js ">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Riverdale Weather | Personal Weather Station: KNYBRONX33 by Wunderground.com | Weather Underground
#   </title>
#   <link href="//icons.wxug.com/" rel="dns-prefetch"/>
#   <link href="//api-ak.wunderground.com/" rel="dns-prefetch"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Weather Underground provides local &amp; long range Weather Forecast, weather reports, maps &amp; tropical weather conditions for locations worldwide." name="description"/>
# ...

# %%
a=soup.find_all('span', class_='subheading')
a0=a[0].contents

# %%
a=soup.find_all('span', class_='wx-data')

# %%
a
# Out:
# [<span class="wx-data" data-station="KNYBRONX33" data-variable="temperature">\n<span class="wx-value">80.1</span>\n<span class="wx-unit">\xb0F</span>\n</span>,
#  <span class="wx-data" data-station="KNYBRONX33" data-variable="feelslike">\n<span class="wx-value">81</span>\n<span class="wx-unit">\xb0F</span>\n</span>,
#  <span class="wx-data " data-station="KNYBRONX33" data-variable="wind_dir">\n  Wind from\n  <span class="wx-value">--</span>\n</span>,
#  <span class="wx-data" data-station="KNYBRONX33" data-variable="dewpoint">\n<span class="wx-value">61</span>\n<span class="wx-unit">\xb0F</span>\n</span>,
#  <span class="wx-data" data-station="KNYBRONX33" data-variable="humidity">\n<span class="wx-value">52</span><span class="wx-unit">%</span>\n</span>,
#  <span class="wx-data" data-station="KNYBRONX33" data-variable="precip_rate">\n<span class="wx-value"> -- </span>\n<span class="wx-unit"></span>\n</span>,
# ...

# %%
r
# Out:
# '\n<!DOCTYPE html>\n<!--[if IE 9]> <html class="no-js ie9"> <![endif]-->\n<!--[if gt IE 9]><!--> <html class="no-js "> <!--<![endif]-->\n\t<head>\n\t\t<title>Riverdale Weather | Personal Weather Station: KNYBRONX33 by Wunderground.com | Weather Underground</title>\n\t\t<link href="//icons.wxug.com/" rel="dns-prefetch" />\n\t\t<link href="//api-ak.wunderground.com/" rel="dns-prefetch" />\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t\t<meta name="description" content="Weather Underground provides local & long range Weather Forecast, weather reports, maps & tropical weather conditions for locations worldwide." />\n\t\t<meta name="keywords" content="Weather, Weather Underground, Riverdale Weather | Personal Weather Station: KNYBRONX33 by Wunderground.com, forecasts, current conditions, rain, snow, hurricane, tornado, storm, thunderstorm, tropical storm, wundermap, ski con
# ...
